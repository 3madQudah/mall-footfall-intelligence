# %% [markdown]
# #### ============================================
# ###  1. Import Libraries
# #### ============================================

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### ============================================
# ###  2. Read a Data
# #### ============================================

# %%
Data = pd.read_csv("/Users/mac/Desktop/Zain Projects/Task 2 Visitor Mall Dataset/data/raw/total_visitors_per_mall.csv")

# %% [markdown]
# #### ============================================
# ###  3. Check a Data
# #### ============================================

# %%
Data.head()
# Out:
#    SUBSCRIBER_ID           VISIT_DATE         MALL_NAME HOME_GOVERNORATE  \
# 0          11121  2022-11-08 13:18:15       Sunset Mall    Governorate 1
# 1          11122  2022-11-19 15:28:46  City Center Mall    Governorate 2
# 2          11122  2022-11-04 11:44:39       Sunset Mall    Governorate 2
# 3          11123  2022-11-05 14:52:57  City Center Mall    Governorate 1
# 4          11124  2022-11-07 17:43:37        Oasis Mall    Governorate 2
#
#   WORK_GOVERNORATE NATIONALITY ARPU_BRACKET DEVICE_OS     AGE_BRACKET  GENDER  \
# 0    Governorate 1     Citizen          Low       iOS  > 25 and <= 45  Female
# 1    Governorate 2     Citizen         High       iOS  > 25 and <= 45    Male
# 2    Governorate 2     Citizen         High       iOS  > 25 and <= 45    Male
# 3    Governorate 1     Citizen          Low       iOS           <= 18    Male
# 4    Governorate 2     Citizen         High       iOS            > 45    Male
#
# ...

# %%
Data.tail()
# Out:
#         SUBSCRIBER_ID           VISIT_DATE         MALL_NAME HOME_GOVERNORATE  \
# 899531         378366  2022-11-15 19:14:14      Century mall    Governorate 1
# 899532         378366  2022-11-27 15:05:58      Century mall    Governorate 1
# 899533         378366  2022-11-24 14:14:29  City Center Mall    Governorate 1
# 899534         378366  2022-11-24 21:24:54  City Center Mall    Governorate 1
# 899535         378366  2022-11-25 11:49:57  City Center Mall    Governorate 1
#
#        WORK_GOVERNORATE NATIONALITY ARPU_BRACKET DEVICE_OS AGE_BRACKET GENDER  \
# 899531    Governorate 1     Citizen         High   Android        > 45   Male
# 899532    Governorate 1     Citizen         High   Android        > 45   Male
# 899533    Governorate 1     Citizen         High   Android        > 45   Male
# 899534    Governorate 1     Citizen         High   Android        > 45   Male
# 899535    Governorate 1     Citizen         High   Android        > 45   Male
#
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899536 entries, 0 to 899535
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   SUBSCRIBER_ID     899536 non-null  int64
#  1   VISIT_DATE        899536 non-null  object
#  2   MALL_NAME         899536 non-null  object
#  3   HOME_GOVERNORATE  899536 non-null  object
#  4   WORK_GOVERNORATE  899536 non-null  object
#  5   NATIONALITY       899536 non-null  object
#  6   ARPU_BRACKET      899536 non-null  object
#  7   DEVICE_OS         899536 non-null  object
#  8   AGE_BRACKET       899536 non-null  object
#  9   GENDER            899536 non-null  object
#  10  STUDENT           899536 non-null  object
#  11  IS_EMPLOYEE       899536 non-null  int64
#  12  CREDIT_CATEGORY   899536 non-null  object
#  13  YEAR              899536 non-null  int64
#  14  MONTH             899536 non-null  object
#  15  DAY               899536 non-null  int64
# ...

# %% [markdown]
# #### ============================================
# ###  4. Check a null Data and Duplicate
# #### ============================================

# %%
Data.isnull().sum()
# Out:
# SUBSCRIBER_ID            0
# VISIT_DATE               0
# MALL_NAME                0
# HOME_GOVERNORATE         0
# WORK_GOVERNORATE         0
# NATIONALITY              0
# ARPU_BRACKET             0
# DEVICE_OS                0
# AGE_BRACKET              0
# GENDER                   0
# STUDENT                  0
# IS_EMPLOYEE              0
# CREDIT_CATEGORY          0
# YEAR                     0
# MONTH                    0
# DAY                      0
# Day                      0
# TIME_DIFF           507657
# dtype: int64

# %%
Data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### ============================================
# ###  5. Cleaning a Dataset
# #### ============================================

# %% [markdown]
# ###  5.1 Drop a TIME_DIFF Column

# %%
Data.drop(columns=['TIME_DIFF'], inplace=True)

# %% [markdown]
# ###  5.2 Drop a Day Column

# %%
Data.drop(columns=['Day'], inplace=True)

# %% [markdown]
# ###  5.3 Drop a Month Column

# %%
Data.drop(columns=['MONTH'], inplace=True)

# %% [markdown]
# ###  5.4 Treatment a Words inside a Colmuns

# %%
Data['CREDIT_CATEGORY'] = Data['CREDIT_CATEGORY'].replace('Excelent', 'Excellent')

# %%
Data.isnull().sum()
# Out:
# SUBSCRIBER_ID       0
# VISIT_DATE          0
# MALL_NAME           0
# HOME_GOVERNORATE    0
# WORK_GOVERNORATE    0
# NATIONALITY         0
# ARPU_BRACKET        0
# DEVICE_OS           0
# AGE_BRACKET         0
# GENDER              0
# STUDENT             0
# IS_EMPLOYEE         0
# CREDIT_CATEGORY     0
# YEAR                0
# DAY                 0
# dtype: int64

# %% [markdown]
# #### ============================================
# ###  6. Save a Cleaning Data
# #### ============================================

# %%
Data.to_csv('total_visitors_per_mall_cleaned.csv', index=False)
